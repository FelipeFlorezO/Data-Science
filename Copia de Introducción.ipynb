# %% [markdown]
# **Machine Learning con Python**\
# Laboratorio semana 2
#
# ---
#
# **Preparado por:** Yesid Ospitia Medina
#
# ---

# %% [markdown]
# **PASO 1: Importar las librerías necesarias.**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **PASO 2: Proceso para cargar archivos CSV a Pandas.**

# %%
dataset="vinos.csv"
df= pd.read_csv(dataset)
df_quality=pd.DataFrame(df,columns=["quality", "alcohol"])

# %% [markdown]
# **PASO 3: Generación de gráficos con Matploitlib**

# %%
df.plot.box(vert=False);
df_quality.plot.box(vert=False);
